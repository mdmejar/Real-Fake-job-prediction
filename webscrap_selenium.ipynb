# %%
import requests 
from bs4 import BeautifulSoup
from selenium import webdriver
import time
from io import BytesIO
from PIL import Image, UnidentifiedImageError
from selenium import webdriver
from selenium.webdriver.edge.service import Service
import html5lib
import pandas as pd

# %%
column_titles = ["Company name", "Job title", "LPA", "Experience","Comapny Logo"]

# %%
df = pd.DataFrame(columns = column_titles)
df
# Out:
# Empty DataFrame
# Columns: [Company name, Job title, LPA, Experience, Comapny Logo]
# Index: []

# %%
def download_image(url, filename):
    response = requests.get(url)
    try:
        img = Image.open(BytesIO(response.content))
        img.save(filename)
    except UnidentifiedImageError:
        return None
    
    except Exception as e:
        return None

company_logos = []

def add_data(soup):
    results = soup.find_all(class_ = 'cust-job-tuple layout-wrapper lay-2 sjw__tuple')
    for result in results:
        li =[]
        job_title = result.find(class_ = 'title').text
        try: 
            company_name = result.find(class_ = "comp-name mw-25").text
        except AttributeError:
            comapny_name = result.find(class_ = "comp-name").text
        LPA = result.find(class_= "ni-job-tuple-icon ni-job-tuple-icon-srp-rupee sal").text
        try:
            Experience = result.find(class_ ="ni-job-tuple-icon ni-job-tuple-icon-srp-date exp").text
        except AttributeError:
            Experience = result.find(class_ ="ni-job-tuple-icon ni-job-tuple-icon-srp-experience exp").text
        logo = result.find('img', class_="logoImage")
    
        if logo:
            logo_url = logo['src']
            filename = f"Image/logo_{len(company_logos)}.png"
            download_image(logo_url, filename)
            company_logos.append(filename)
        else:
            company_logos.append(None)
        li.extend([job_title, company_name, LPA, Experience,company_logos[-1]])
        length = len(df)
        df.loc[length] = li
        print(li)
    
    
def Check_Next_Link(soup):
    link_tag = soup.find_all('a', class_ ="styles_btn-secondary__2AsIP")

    base_link = "https://www.naukri.com"
    for link in link_tag:
        if link and 'href' in link.attrs:
            if link.text == 'Next':
                next_link = base_link + link['href']
                driver.get(next_link)
                add_data(BeautifulSoup(driver.page_source, 'html.parser'))    
            else:
                print("thats the end")

                
url = "https://www.naukri.com/financial-analyst-jobs-in-mumbai?k=financial+analyst&l=mumbai"
s = Service(executable_path=r"C:\Program Files (x86)\Microsoft\Edge\Application\msedgedriver.exe")
driver = webdriver.Edge(service=s)
driver.get(url)

time.sleep(3)

soup = BeautifulSoup(driver.page_source,'html.parser')
add_data(soup)
# Out:
# ['Financial Analyst', 'eClerx', 'Not disclosed', '19 Apr', 'Image/logo_0.png']
# ['Finance Analyst', 'eClerx', 'Not disclosed', '3-5 Yrs', 'Image/logo_1.png']
# ['Finance Analyst', 'eClerx', 'Not disclosed', '3-5 Yrs', None]
# ['Finance Analyst', 'eClerx', '5-12 Lacs PA', '5-10 Yrs', None]
# ['Hiring For Financial Analyst For Mumbai Location', 'TeamLease', '5-14 Lacs PA', '3-5 Yrs', 'Image/logo_4.png']
# ['Finance Analyst', 'TeamLease', 'Not disclosed', '1-4 Yrs', None]
# ['Finance Analyst', 'TeamLease', 'Not disclosed', '1-4 Yrs', None]
# ['Financial Analyst', 'THE GUARDIANS REAL ESTATE ADVISORY', '6-10 Lacs PA', '2-4 Yrs', None]
# ['Analyst - Finance', 'R B N A & Associates LLP', '6-8 Lacs PA', '3-4 Yrs', None]
# ['Strategy (Financial Analyst)', 'R B N A & Associates LLP', '17-25 Lacs PA', '10-17 Yrs', None]
# ['Financial Analyst - Mumbai', 'R B N A & Associates LLP', '2-3 Lacs PA', '0 Yrs', None]
# ...

# %%
df
# Out:
#                                         Company name  \
# 0                                  Financial Analyst
# 1                                    Finance Analyst
# 2                                    Finance Analyst
# 3                                    Finance Analyst
# 4   Hiring For Financial Analyst For Mumbai Location
# 5                                    Finance Analyst
# 6                                    Finance Analyst
# 7                                  Financial Analyst
# 8                                  Analyst - Finance
# 9                       Strategy (Financial Analyst)
# 10                        Financial Analyst - Mumbai
# 11                       Operational Finance Analyst
# 12                                   Finance Analyst
# 13                                 Financial Analyst
# 14                                 Financial Analyst
# 15                                   Finance Analyst
# 16                                 Financial Analyst
# ...

# %% [markdown]
# # TESTING

# %%
from selenium import webdriver
from selenium.webdriver.edge.service import Service
from bs4 import BeautifulSoup

# Initialize the driver
service = Service(executable_path=r"C:\Program Files (x86)\Microsoft\Edge\Application\msedgedriver.exe")  # Replace with your preferred browser
driver = webdriver.Edge(service=service)

# Navigate to the website
url = "https://www.naukri.com/financial-analyst-jobs-in-mumbai?k=financial+analyst&l=mumbai"
driver.get(url)

# Parse the HTML content using Beautiful Soup
soup = BeautifulSoup(driver.page_source, 'html.parser')

# Find the "Next" button
next_button = soup.find('a', class_="styles_btn-secondary__2AsIP")

# Check if the "Next" button exists and has an href attribute
if next_button.text == "Next" and 'href' in next_button.attrs:
    # Extract the href link from the "Next" button
    next_page = next_button['href']
    print(next_page)
else:
    print("The 'Next' button does not exist or does not have an href attribute.")

# Quit the driver after you're done
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 20
#      17 next_button = soup.find('a', class_="styles_btn-secondary__2AsIP")
#      19 # Check if the "Next" button exists and has an href attribute
# ---> 20 if next_button.text == "Next" and 'href' in next_button.attrs:
#      21     # Extract the href link from the "Next" button
#      22     next_page = next_button['href']
#      23     print(next_page)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
import sys
import subprocess
from selenium import webdriver
from selenium.webdriver.edge.service import Service
from bs4 import BeautifulSoup
import time

# Initialize the driver
# Replace the path with the path to the msedgedriver.exe on your system
service = Service(executable_path=r"C:\Program Files (x86)\Microsoft\Edge\Application\msedgedriver.exe")  # Replace with your preferred browser
driver = webdriver.Edge(service=service)

def download_image(url, filename):
    response = requests.get(url)
    try:
        img = Image.open(BytesIO(response.content))
        img.save(filename)
    except UnidentifiedImageError:
        return None
    
    except Exception as e:
        return None

company_logos = []

def add_data(soup):
    results = soup.find_all(class_ = 'cust-job-tuple layout-wrapper lay-2 sjw__tuple')
    for result in results:
        li =[]
        job_title = result.find(class_ = 'title').text
        try: 
            company_name = result.find(class_ = "comp-name mw-25").text
        except AttributeError:
            comapny_name = result.find(class_ = "comp-name").text
        LPA = result.find(class_= "ni-job-tuple-icon ni-job-tuple-icon-srp-rupee sal").text
        try:
            Experience = result.find(class_ ="ni-job-tuple-icon ni-job-tuple-icon-srp-date exp").text
        except AttributeError:
            Experience = result.find(class_ ="ni-job-tuple-icon ni-job-tuple-icon-srp-experience exp").text
        logo = result.find('img', class_="logoImage")
    
        if logo:
            logo_url = logo['src']
            filename = f"Image/logo_{len(company_logos)}.png"
            download_image(logo_url, filename)
            company_logos.append(filename)
        else:
            company_logos.append(None)
        li.extend([job_title, company_name, LPA, Experience,company_logos[-1]])
        length = len(df)
        df.loc[length] = li
        print(li)


def get_page_urls(url):
    current_url = url
    while current_url:
        previous_url = current_url
        driver.get(current_url)
        time.sleep(3)
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        add_data(soup)
        print("scrape all the tags from the specfic class name")
        next_pages = soup.find_all('a', class_ ="styles_btn-secondary__2AsIP")
        for next_page in next_pages:
            if next_page and 'href' in next_page.attrs and next_page.text == "Next":
                current_url = "https://www.naukri.com" + next_page['href']
                print(current_url)
        
        if previous_url == current_url:
            break
    driver.quit()
    return "work done"

# Ulta website link
url = "https://www.naukri.com/financial-analyst-jobs-in-mumbai?k=financial+analyst&l=mumbai"
page_urls = get_page_urls(url)

print(page_urls)
# Out:
# ['Financial Analyst', 'eClerx', 'Not disclosed', '06 May - 08 May', 'Image/logo_0.png']
# ['Financial Analyst - Route Mobile', 'Route Mobile (RML)', 'Not disclosed', '4-5 Yrs', 'Image/logo_1.png']
# ['Hiring  Financial Analyst based at Mumbai', 'TeamLease', '4-8.5 Lacs PA', '0-4 Yrs', 'Image/logo_2.png']
# ['Financial Analyst', 'CA Monk', 'Not disclosed', '1-3 Yrs', 'Image/logo_3.png']
# ['Finance Analyst', 'Chryso', '7-10 Lacs PA', '3-7 Yrs', 'Image/logo_4.png']
# ['Finance Analyst', 'Nobel Hygiene', 'Not disclosed', '2-4 Yrs', 'Image/logo_5.png']
# ['Financial Analyst', 'Burns and Mc Donnells Engineering India', 'Not disclosed', '6-7 Yrs', 'Image/logo_6.png']
# ['Financial Analyst cum Deal Origination', 'Asit C Mehta Investment Interrmediates (ACMIIL)', '4.5-9 Lacs PA', '1-6 Yrs', 'Image/logo_7.png']
# ['Financial Analyst', 'Bhanix', 'Not disclosed', '3-5 Yrs', None]
# ['CA - (Financial Analyst)', 'Bhanix', '12-14 Lacs PA', '2-4 Yrs', None]
# ...

# %%
import sys
import subprocess
from selenium import webdriver
from selenium.webdriver.edge.service import Service
from bs4 import BeautifulSoup
import time

# Initialize the driver
# Replace the path with the path to the msedgedriver.exe on your system
service = Service(executable_path=r"C:\Program Files (x86)\Microsoft\Edge\Application\msedgedriver.exe")  # Replace with your preferred browser
driver = webdriver.Edge(service=service)

def download_image(url, filename):
    response = requests.get(url)
    try:
        img = Image.open(BytesIO(response.content))
        img.save(filename)
    except UnidentifiedImageError:
        return None
    
    except Exception as e:
        return None

company_logos = []

def add_data(soup):
    results = soup.find_all(class_ = 'cust-job-tuple layout-wrapper lay-2 sjw__tuple')
    for result in results:
        li =[]
        job_title = result.find(class_ = 'title').text
        try: 
            company_name = result.find(class_ = "comp-name mw-25").text
        except AttributeError:
            comapny_name = result.find(class_ = "comp-name").text
        LPA = result.find(class_= "ni-job-tuple-icon ni-job-tuple-icon-srp-rupee sal").text
        try:
            Experience = result.find(class_ ="ni-job-tuple-icon ni-job-tuple-icon-srp-date exp").text
        except AttributeError:
            Experience = result.find(class_ ="ni-job-tuple-icon ni-job-tuple-icon-srp-experience exp").text
        logo = result.find('img', class_="logoImage")
    
        if logo:
            logo_url = logo['src']
            filename = f"Image/logo_{len(company_logos)}.png"
            download_image(logo_url, filename)
            company_logos.append(filename)
        else:
            company_logos.append(None)
        li.extend([job_title, company_name, LPA, Experience,company_logos[-1]])
        length = len(df)
        df.loc[length] = li
        print(li)
    return soup.find_all('a', class_ ="styles_btn-secondary__2AsIP")


def get_page_urls(url):
    current_url = url
    while current_url:
        previous_url = current_url
        driver.get(current_url)
        time.sleep(2)
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        print("scrape all the tags from the specfic class name")
        next_pages = add_data(soup)
        for next_page in next_pages:
            if next_page and 'href' in next_page.attrs and next_page.text == "Next":
                current_url = "https://www.naukri.com" + next_page['href']
                print(current_url)
        
        if previous_url == current_url:
            break
    driver.quit()
    return "work done"

# Ulta website link
url = "https://www.naukri.com/financial-analyst-jobs-in-mumbai-5"
page_urls = get_page_urls(url)

print(page_urls)
# Out:
# scrape all the tags from the specfic class name
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[14], line 77
#      75 # Ulta website link
#      76 url = "https://www.naukri.com/financial-analyst-jobs-in-mumbai-5"
# ---> 77 page_urls = get_page_urls(url)
#      79 print(page_urls)
#
# Cell In[14], line 64, in get_page_urls(url)
#      62 soup = BeautifulSoup(driver.page_source, 'html.parser')
#      63 print("scrape all the tags from the specfic class name")
# ---> 64 next_pages = add_data(soup)
#      65 for next_page in next_pages:
#      66     if next_page and 'href' in next_page.attrs and next_page.text == "Next":
#
# Cell In[14], line 49, in add_data(soup)
#      47 else:
#      48     company_logos.append(None)
# ---> 49 li.extend([job_title, company_name, LPA, Experience,company_logos[-1]])
#      50 length = len(df)
#      51 df.loc[length] = li
#
# ...

# %%
import sys
import subprocess
from selenium import webdriver
from selenium.webdriver.edge.service import Service
from bs4 import BeautifulSoup
import time
import requests
from PIL import Image
from io import BytesIO
import pandas as pd

# Initialize the driver
service = Service(executable_path=r"C:\Program Files (x86)\Microsoft\Edge\Application\msedgedriver.exe")
driver = webdriver.Edge(service=service)

def download_image(url, filename):
    try:
        response = requests.get(url)
        img = Image.open(BytesIO(response.content))
        img.save(filename)
        return filename
    except (UnidentifiedImageError, Exception) as e:
        print(f"Error downloading image: {e}")
        return None

def extract_job_data(result):
    # here we exrtact the Job title, Company Name, LPA, Experience and Logo
    job_title = result.find(class_='title').text
    company_name = result.find(class_='comp-name mw-25').text if result.find(class_='comp-name mw-25') else result.find(class_='comp-name').text
    company_name = company_name or 'Unknown Company'
    lpa = result.find(class_='ni-job-tuple-icon ni-job-tuple-icon-srp-rupee sal').text
    experience = result.find(class_='ni-job-tuple-icon ni-job-tuple-icon-srp-date exp').text if result.find(class_='ni-job-tuple-icon ni-job-tuple-icon-srp-date exp') else result.find(class_='ni-job-tuple-icon ni-job-tuple-icon-srp-experience exp').text if result.find(class_='ni-job-tuple-icon ni-job-tuple-icon-srp-experience exp') else 'Unknown'
    logo = result.find('img', class_='logoImage')
    logo_url = logo['src'] if logo else None
    return job_title, company_name, lpa, experience, logo_url

def add_data(soup, company_logos, df):
    #here we add the data from the extracted data 
    results = soup.find_all(class_='cust-job-tuple layout-wrapper lay-2 sjw__tuple')
    for result in results:
        job_title, company_name, lpa, experience, logo_url = extract_job_data(result)
        if logo_url:
            filename = f"Image/logo_{len(company_logos)}.png"
            downloaded_logo = download_image(logo_url, filename)
            company_logos.append(downloaded_logo)
        else:
            company_logos.append(None)
        df.loc[len(df)] = [job_title, company_name, lpa, experience, company_logos[-1]]
    return soup.find_all('a', class_='styles_btn-secondary__2AsIP')

def get_page_urls(url, company_logos, df):
    # Here we get the urls from the given link
    current_url = url
    while current_url:
        previous_url = current_url
        driver.get(current_url)
        time.sleep(2)
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        print("Scraped all tags from the specific class name")
        next_pages = add_data(soup, company_logos, df)
        for next_page in next_pages:
            if next_page and 'href' in next_page.attrs and next_page.text == "Next":
                current_url = "https://www.naukri.com" + next_page['href']
                print(current_url)
        if previous_url == current_url:
            break
    driver.quit()
    return "Work done"

# Ulta website link
url = "https://www.naukri.com/financial-analyst-jobs-in-mumbai?k=financial+analyst&l=mumbai"
company_logos = []
df = pd.DataFrame(columns=['Job Title', 'Company Name', 'LPA', 'Experience', 'Logo'])

page_urls = get_page_urls(url, company_logos, df)
print(page_urls)
df # Print the scraped data
# Out:
# Scraped all tags from the specific class name
# https://www.naukri.com/financial-analyst-jobs-in-mumbai-2
# Scraped all tags from the specific class name
# https://www.naukri.com/financial-analyst-jobs-in-mumbai-3
# Scraped all tags from the specific class name
# https://www.naukri.com/financial-analyst-jobs-in-mumbai-4
# Scraped all tags from the specific class name
# https://www.naukri.com/financial-analyst-jobs-in-mumbai-5
# Scraped all tags from the specific class name
# Work done
#                                     Job Title  \
# 0                           Financial Analyst
# 1                             Finance Analyst
# 2            Financial Analyst - Route Mobile
# 3   Hiring  Financial Analyst based at Mumbai
# 4                           Financial Analyst
# ..                                        ...
# 74                     Financial Analyst - II
# 75          Intern/ Analyst Corporate Finance
# 76              Finance Planning And Analysis
# ...

# %%
import sys
import subprocess
from selenium import webdriver
from selenium.webdriver.edge.service import Service
from bs4 import BeautifulSoup
import time
import requests
from PIL import Image
from io import BytesIO
import pandas as pd

# Initialize the driver
service = Service(executable_path=r"C:\Program Files (x86)\Microsoft\Edge\Application\msedgedriver.exe")
driver = webdriver.Edge(service=service)

def download_image(url, filename):
    try:
        response = requests.get(url)
        img = Image.open(BytesIO(response.content))
        img.save(filename)
        return filename
    except (UnidentifiedImageError, Exception) as e:
        print(f"Error downloading image: {e}")
        return None

def extract_job_data(result):
    # here we exrtact the Job title, Company Name, LPA, Experience and Logo
    job_title = result.find(class_='title').text
    company_name = result.find(class_='comp-name mw-25').text if result.find(class_='comp-name mw-25') else result.find(class_='comp-name').text
    company_name = company_name or 'Unknown Company'
    lpa = result.find(class_='ni-job-tuple-icon ni-job-tuple-icon-srp-rupee sal').text
    experience = result.find(class_='ni-job-tuple-icon ni-job-tuple-icon-srp-date exp').text if result.find(class_='ni-job-tuple-icon ni-job-tuple-icon-srp-date exp') else result.find(class_='ni-job-tuple-icon ni-job-tuple-icon-srp-experience exp').text if result.find(class_='ni-job-tuple-icon ni-job-tuple-icon-srp-experience exp') else 'Unknown'
    logo = result.find('img', class_='logoImage')
    logo_url = logo['src'] if logo else None
    return job_title, company_name, lpa, experience, logo_url

def add_data(soup, company_logos, df):
    #here we add the data from the extracted data 
    results = soup.find_all(class_='cust-job-tuple layout-wrapper lay-2 sjw__tuple')
    for result in results:
        job_title, company_name, lpa, experience, logo_url = extract_job_data(result)
        if logo_url:
            filename = f"Image/logo_{len(company_logos)}.png"
            downloaded_logo = download_image(logo_url, filename)
            company_logos.append(downloaded_logo)
        else:
            company_logos.append(None)
        df.loc[len(df)] = [job_title, company_name, lpa, experience, company_logos[-1]]
    return soup.find_all('a', class_='styles_btn-secondary__2AsIP')

def get_page_urls(url, company_logos, df):
    # Here we get the urls from the given link
    current_url = url
    while current_url:
        previous_url = current_url
        driver.get(current_url)
        time.sleep(2)
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        print("Scraped all tags from the specific class name")
        next_pages = add_data(soup, company_logos, df)
        for next_page in next_pages:
            if next_page and 'href' in next_page.attrs and next_page.text == "Next":
                current_url = "https://www.naukri.com" + next_page['href']
                print(current_url)
        if previous_url == current_url:
            break
    driver.quit()
    return "Work done"

# Ulta website link
url = "https://www.naukri.com/financial-analyst-jobs-in-mumbai?k=financial+analyst&l=mumbai"
company_logos = []
df = pd.DataFrame(columns=['Job Title', 'Company Name', 'LPA', 'Experience', 'Logo'])

page_urls = get_page_urls(url, company_logos, df)
print(page_urls)
df # Print the scraped data
# Out:
# Scraped all tags from the specific class name
# https://www.naukri.com/financial-analyst-jobs-in-mumbai-2
# Scraped all tags from the specific class name
# https://www.naukri.com/financial-analyst-jobs-in-mumbai-3
# Scraped all tags from the specific class name
# https://www.naukri.com/financial-analyst-jobs-in-mumbai-4
# Scraped all tags from the specific class name
# https://www.naukri.com/financial-analyst-jobs-in-mumbai-5
# Scraped all tags from the specific class name
# https://www.naukri.com/financial-analyst-jobs-in-mumbai-6
# Scraped all tags from the specific class name
# https://www.naukri.com/financial-analyst-jobs-in-mumbai-7
# Scraped all tags from the specific class name
# https://www.naukri.com/financial-analyst-jobs-in-mumbai-8
# Scraped all tags from the specific class name
# https://www.naukri.com/financial-analyst-jobs-in-mumbai-9
# Scraped all tags from the specific class name
# https://www.naukri.com/financial-analyst-jobs-in-mumbai-10
# ...

# %%
df.to_csv(r'C:\Users\Joyal\jupyter files\Aug Batch Project Details\naukri_comapanies.csv')

# %%
df = pd.read_csv(r'job_posting_feedback.csv')

# %%
df
# Out:
#     Unnamed: 0                                   Company Name  \
# 0            0                             Jmedia Corporation
# 1            1                                         google
# 2            2                                            Job
# 3            3                                           Vlcc
# 4            4                      Foreign IT consulting MNC
# 5            5                    BT e-Serv (India) Pvt. Ltd.
# 6            6                  Leading Indian MNC in Telecom
# 7            7                                       Marriott
# 8            8                                       Evolearn
# 9            9                       Large Internet Corporate
# 10          10              Becquer Energy India Sales Office
# 11          11                               Internet Unicorn
# 12          12  Hiring for Client and industry is IT Industry
# 13          13                               Centre For Sight
# ...

# %%
data = { 'Company Name' : ['Accenture','Large IT MNC','Foreign MNC in Analytics','Hexaware Technologies','Accenture','Policybazaar','InsurTech Unicorn','Posted by Smart Steps HR Services','Fortune 500 Product-based MNC','Akshaya Patra Foundation','Wikilabs India','Auto Tech Unicorn','McGraw Hill','Big 4 Consulting Firm','Siemens'],
        'Reference Link':['https://www.naukri.com/job-listings-s-c-global-network-ai-life-sciences-data-science-analyst-accenture-solutions-pvt-ltd-mumbai-gurugram-delhi-ncr-2-to-5-years-280524908570',
                         'https://www.naukri.com/job-listings-data-science-manager-noida-mumbai-pune-gurgaon-gurugram-bangalore-bengaluru-8-to-13-years-130324902211?src=gnbjobs_homepage_srch&sid=1717389240059481&xp=2&px=1',
                         'https://www.naukri.com/job-listings-data-analyst-new-delhi-pune-gurgaon-gurugram-bangalore-bengaluru-0-to-2-years-110424902160?src=gnbjobs_homepage_srch&sid=1717389240059481&xp=4&px=1',
                         'https://www.naukri.com/job-listings-analytics-data-science-and-iot-lead-hexaware-technologies-ltd-kolkata-mumbai-new-delhi-hyderabad-pune-chennai-bengaluru-5-to-7-years-280524500124',
                          'https://www.naukri.com/job-listings-s-c-global-network-ai-life-sciences-data-science-consultant-accenture-solutions-pvt-ltd-gurugram-2-to-6-years-270524909334',
                          'https://www.naukri.com/job-listings-human-resource-executive-policybazaar-gurugram-0-to-3-years-030124005844',
                          'https://www.naukri.com/job-listings-hr-executive-hyderabad-secunderabad-gurgaon-gurugram-bangalore-bengaluru-trivandrum-thiruvananthapuram-1-to-5-years-070524900717?src=gnbjobs_homepage_srch&sid=17173897823446507&xp=2&px=1',
                          'https://www.naukri.com/job-listings-hr-executive-work-from-home-smart-steps-hr-services-new-delhi-0-to-2-years-080224005600',
                          'https://www.naukri.com/job-listings-hr-executive-noida-1-to-2-years-290524903245?src=gnbjobs_homepage_srch&sid=17173897823446507&xp=4&px=1',
                          'https://www.naukri.com/job-listings-hr-sr-executive-akshaya-patra-foundation-new-delhi-gurugram-delhi-ncr-2-to-7-years-201023006212',
                          'https://www.naukri.com/job-listings-business-analyst-sales-intern-iits-only-wikilabs-india-greater-noida-0-to-1-years-020624001357',
                          'https://www.naukri.com/job-listings-mechanical-fresher-hyderabad-secunderabad-ahmedabad-gurgaon-gurugram-0-to-1-years-180524901387?src=gnbjobs_homepage_srch&sid=1717390876141109&xp=2&px=1',
                          'https://www.naukri.com/job-listings-senior-executive-production-services-mcgraw-hill-education-noida-0-to-5-years-280524500207',
                          'https://www.naukri.com/job-listings-planning-manager-noida-mumbai-lucknow-gurgaon-gurugram-7-to-10-years-300324901061?src=gnbjobs_homepage_srch&sid=1717390876141109&xp=4&px=1',
                          'https://www.naukri.com/job-listings-tool-crib-room-manager-siemens-limited-gurugram-0-to-6-years-270524501959'
                         ],
        'Is Real Posting':['yes','no','no','yes','yes','yes','no','no','no','yes','yes','no','yes','no','yes'],
    
}

# %%
df2 = pd.DataFrame.from_dict(data)

# %%
df4  =  pd.concat([df, df2], ignore_index = True)
df4.reset_index()
df4 = df4.drop('Unnamed: 0', axis=1)

# %%
df4.reset_index()
# Out:
#     index                                   Company Name  \
# 0       0                             Jmedia Corporation
# 1       1                                         google
# 2       2                                            Job
# 3       3                                           Vlcc
# 4       4                      Foreign IT consulting MNC
# 5       5                    BT e-Serv (India) Pvt. Ltd.
# 6       6                  Leading Indian MNC in Telecom
# 7       7                                       Marriott
# 8       8                                       Evolearn
# 9       9                       Large Internet Corporate
# 10     10              Becquer Energy India Sales Office
# 11     11                               Internet Unicorn
# 12     12  Hiring for Client and industry is IT Industry
# 13     13                               Centre For Sight
# 14     14                   Leading Indian MNC in Pharma
# ...

# %%
df4.to_csv(r'job_posting_feedback.csv')
